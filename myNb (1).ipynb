# %% [markdown]
# <a href=https://www.cognitiveclass.ai>Cognitive Class</a>

# %% [markdown]
# <!doctype html>
# <html lang="en" style="height: 100%">
#
# <head>
#   <meta charset="UTF-8">
#   <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#
#   <title>Markdown Here Test</title>
#   <meta name="description" content="">
#   <meta name="author" content="">
#
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
# </head>
#
# <body style="height: 100%">
#   <iframe style="height: 100%; width: 100%;">
#   </iframe>
#
#   <script>
#     document.addEventListener('DOMContentLoaded', function() {
#       var body = document.querySelector('iframe').contentDocument.body;
#       body.setAttribute('contenteditable', true);
#       body.focus();
#     });
#   </script>
# </body>
#
# </html>

# %% [markdown]
# | Stretch/Untouched | ProbDistribution | Accuracy |
# | --- | --- | --- |
# | Stretched | Gaussian | .843 |

# %% [markdown]
# | Name| Roll Number | Grade |
# | --- | --- | --- |
# | Rishabh | 15 | A+ |
# | Riya | 1 | A |

# %% [markdown]
# # This is the title
# ## These are major headings
# ### Welcome to the subheading
# #### This is just fun
# ##### Idk if this exits as well
# 1. Check mate
# 1. Hahah

# %% [markdown]
# __double underscore for bold__ <br>
# **double star for bold**
# _single '-' for italics_
# *single - for italics*

# %% [markdown]
# <font color=blue|red|green|pink|yellow>Text</font>

# %% [markdown]
# <span style="color:red">Check it out **This is Red Bold.** text</span>

# %% [markdown]
# <span style="color:blue">some *This is Blue italic.* text</span>

# %% [markdown]
# <span style="color:green">Lets try this as well text</span>

# %% [markdown]
# <span style="color:yellow">And this text</span>

# %% [markdown]
# # cheat sheat
# `monospace text`
# see this is the normal text

# %% [markdown]
# "br in <> " for line break

# %% [markdown]
# $ mathematical symbols $
# $ a * b $

# %% [markdown]
# $ symbol $

# %% [markdown]
# $ __symbol__ $

# %% [markdown]
# $ + $

# %% [markdown]
# a $ + $ b $ * $ c

# %% [markdown]
# <span style="color:purple"> text </span>

# %% [markdown]
# # grocery list
# > carrots
# > tomatoes

# %% [markdown]
# ## grocery list with different indentation
# ### indented quoting
# > carrots
# > tomatoes
# > potatoes
#
# ### <span style ="color:red">bullets</span>
# - carrots
# - tomatoes
# - potatoes
# <br>
#
# ### numbers
# 1. carrots
# 1. tomatoes
# 1. potatoes

# %% [markdown]
# <img src="url.gif" alt="Alt text that describes the graphic" title="Title text" />

# %% [markdown]
# ![Flag-India.jpg](attachment:Flag-India.jpg)

# %% [markdown]
# ![lambo urus.jpg](attachment:lambo urus.jpg)

# %% [markdown]
# ![roadster.jpg](attachment:roadster.jpg)

# %% [markdown]
# ![lambo urus.jpg](attachment:lambo urus.jpg)

# %% [markdown]
# ![lambo-urus.jpg](attachment:lambo-urus.jpg)

# %% [markdown]
# ![tiger.jpg](attachment:tiger.jpg)

# %% [markdown]
# <p>I will display &#9658;</p>
# <p>I will display &#x25A1;</p>

# %% [markdown]
# [section title]
